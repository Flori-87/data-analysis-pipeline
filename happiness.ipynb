# %%
import numpy as np
import pandas as pd
import os
import sys
module_path = os.path.abspath(os.path.join('funciones.py'))
if module_path not in sys.path:
    sys.path.append(module_path)
from funciones import *

# %%
now = pd.read_csv("2015.csv")
ISO = pd.read_csv("ISO_mejorado.csv")

# %%
ISO = ISO.rename(columns={"country":"Country"})

# %%
now_ISO = now.merge(ISO, how='left',on="Country")

# %%
now_ISO
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
now_ISO = now_ISO.drop(columns=["Unnamed: 0",'Dystopia Residual'])
now_ISO.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'ISO'],
#       dtype='object')

# %%
now_ISO["Income"] = now_ISO["ISO"].apply(getIncome)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# ...

# %%
now_ISO
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
now_ISO["Precipitations/month (mm)"] = now_ISO["ISO"].apply(getPrecip)

# %%
now_ISO
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
now_ISO["Temperatures (ºC)"] = now_ISO["ISO"].apply(getTemp)

# %%
now_ISO
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
now_ISO["Region"].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# Australia and New Zealand           2
# North America                       2
# Name: Region, dtype: int64

# %%
now_ISO = now_ISO.set_index("Happiness Rank")

# %%
now_ISO[now_ISO["Country"] == "Venezuela"].index
# Out:
# Int64Index([23], dtype='int64', name='Happiness Rank')

# %%
now_ISO.iloc[22]
# Out:
# Country                                            Venezuela
# Region                           Latin America and Caribbean
# Happiness Score                                         6.81
# Standard Error                                       0.06476
# Economy (GDP per Capita)                             1.04424
# Family                                               1.25596
# Health (Life Expectancy)                             0.72052
# Freedom                                              0.42908
# Trust (Government Corruption)                        0.11069
# Generosity                                           0.05841
# ISO                                                      VEN
# Income                                                   UMC
# Precipitations/month (mm)                             168.61
# Temperatures (ºC)                                      25.85
# Name: 23, dtype: object

# %%
now_ISO.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# ISO                              0
# Income                           0
# Precipitations/month (mm)        0
# Temperatures (ºC)                0
# dtype: int64

# %%
now_ISO
# Out:
#                     Country                           Region  Happiness Score  \
# Happiness Rank
# 1               Switzerland                   Western Europe            7.587
# 2                   Iceland                   Western Europe            7.561
# 3                   Denmark                   Western Europe            7.527
# 4                    Norway                   Western Europe            7.522
# 5                    Canada                    North America            7.427
# ...                     ...                              ...              ...
# 154                  Rwanda               Sub-Saharan Africa            3.465
# 155                   Benin               Sub-Saharan Africa            3.340
# 156                   Syria  Middle East and Northern Africa            3.006
# 157                 Burundi               Sub-Saharan Africa            2.905
# 158                    Togo               Sub-Saharan Africa            2.839
#
# ...

# %%
now_ISO.to_csv("dataset_clean.csv")
